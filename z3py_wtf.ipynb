# %%
from z3 import *
import itertools

# %% [markdown]
# ## Sorts

# %%
# create uninterpreted sort Node and Epoch
Node = DeclareSort('Node')
Epoch = DeclareSort('Epoch')

# %%
# Functions to extract terms and instantiate quantifiers
def extract_terms(expr, bound=[]):
    termdict = {Node: set(), Epoch: set()}
    if expr.sort() in {Node, Epoch}:
        termdict[expr.sort()] = termdict[expr.sort()] | {expr}
    else:
        if type(expr) == QuantifierRef:
            raise ValueError('Unsupported')
        termdict_children = [extract_terms(child) for child in expr.children()]
        for child_termdict in termdict_children:
            termdict[Node] = termdict[Node] | child_termdict[Node]
            termdict[Epoch] = termdict[Epoch] | child_termdict[Epoch]
    return termdict

def instantiate(expr, termdict):
#     if type(expr) != QuantifierRef or not expr.is_forall():
#         raise ValueError('Unsupported')
    quantified_variables, body = expr #expr.body()
    if not isinstance(body,ExprRef):
        raise ValueError('Unsupported')
    #quantified_variables = [Const(expr.var_name(i), expr.var_sort(i)) for i in range(expr.num_vars())]
    instantiations = list(itertools.product(*[termdict[var.sort()] for var in quantified_variables]))
    print(f'quant_vars: {quantified_variables}')
    print(f'instantiations: {list(instantiations)}')
    print(f'body: {body}')
    print(f'instance: {substitute(body, list(zip(quantified_variables, list(instantiations[0]))))}')
    print(f'zip: {list(zip(quantified_variables, list(instantiations[0])))}')
    return And([substitute(body, list(zip(quantified_variables, list(inst)))) for inst in instantiations[:1]])

# %% [markdown]
# ## State and Model

# %%
class DistLockState():
    def __init__(self, name):
        self.name = name

        # relations
        self.ep = Function(f'{name}.ep', Node, Epoch)
        self.held = Function(f'{name}.held', Node, BoolSort())
        self.transfer = Function(f'{name}.transfer', Epoch, Node, BoolSort())
        self.locked = Function(f'{name}.locked', Epoch, Node, BoolSort())

DistLockState('test_pre') # only for testing

# %%
class DistLockModel():
    def __init__(self):
        # constants
        self.le = Function(f'le', Epoch, Epoch, BoolSort())
        self.zero = Const(f'zero', Epoch)
        self.one = Const(f'one', Epoch)
        self.first = Const(f'first', Node)

        self.states = {}
    
    def get_state(self, name):
        if name not in self.states:
            self.states[name] = DistLockState(name)
        return self.states[name]
    
    def get_axioms(self):
        e1, e2, e3 = Consts('e1 e2 e3', Epoch)
        
        Axioms = ([e1, e2, e3], #ForAll([e1, e2, e3],
            And(
                # reflexivity
                self.le(e1, e1),
                # transitivity
                Implies(And(self.le(e1, e2), self.le(e2, e3)), self.le(e1, e3)),
                # antisymmetry
                Implies(And(self.le(e1, e2), self.le(e2, e1)), e1 == e2),
                # totality
                Or(self.le(e1, e2), self.le(e2, e1)),

                # zero
                self.le(self.zero, e1),
                self.one != self.zero,
            ),
        )

        return Axioms
    
    def get_init_state_cond(self):
        S = self.get_state('init')

        n = Const('n', Node)
        e = Const('e', Epoch)

        cond = ForAll([n, e],
            And(
                S.held(n) == (n == self.first),
                Implies(n != self.first, S.ep(n) == self.zero),
                S.ep(self.first) == self.one,
                S.transfer(e, n) == False,
                S.locked(e, n) == False,
            )
        )

        return cond
    
    def get_interp(self, model: ModelRef):
        # create a dict of all the functions
        interp = {}
        for f in model.decls():
            interp[f.name()] = model.get_interp(f)
        
        return interp

M = DistLockModel()
# only for testing
axiom = M.get_axioms() 
terms = extract_terms(axiom[1])
print(terms)
instantiate(axiom, terms)
#axiom
# Out:
# {Node: set(), Epoch: {one, zero, e1, e2, e3}}
# quant_vars: [e1, e2, e3]
# instantiations: [(one, one, one), (one, one, zero), (one, one, e1), (one, one, e2), (one, one, e3), (one, zero, one), (one, zero, zero), (one, zero, e1), (one, zero, e2), (one, zero, e3), (one, e1, one), (one, e1, zero), (one, e1, e1), (one, e1, e2), (one, e1, e3), (one, e2, one), (one, e2, zero), (one, e2, e1), (one, e2, e2), (one, e2, e3), (one, e3, one), (one, e3, zero), (one, e3, e1), (one, e3, e2), (one, e3, e3), (zero, one, one), (zero, one, zero), (zero, one, e1), (zero, one, e2), (zero, one, e3), (zero, zero, one), (zero, zero, zero), (zero, zero, e1), (zero, zero, e2), (zero, zero, e3), (zero, e1, one), (zero, e1, zero), (zero, e1, e1), (zero, e1, e2), (zero, e1, e3), (zero, e2, one), (zero, e2, zero), (zero, e2, e1), (zero, e2, e2), (zero, e2, e3), (zero, e3, one), (zero, e3, zero), (zero, e3, e1), (zero, e3, e2), (zero, e3, e3), (e1, one, one), (e1, one, zero), (e1, one, e1), (e1, one, e2), (e1, one, e3), (e1, zero, one), (e1, zero, zero), (e1, zero, e1), (e1, zero, e2), (e1, zero, e3), (e1, e1, one), (e1, e1, zero), (e1, e1, e1), (e1, e1, e2), (e1, e1, e3), (e1, e2, one), (e1, e2, zero), (e1, e2, e1), (e1, e2, e2), (e1, e2, e3), (e1, e3, one), (e1, e3, zero), (e1, e3, e1), (e1, e3, e2), (e1, e3, e3), (e2, one, one), (e2, one, zero), (e2, one, e1), (e2, one, e2), (e2, one, e3), (e2, zero, one), (e2, zero, zero), (e2, zero, e1), (e2, zero, e2), (e2, zero, e3), (e2, e1, one), (e2, e1, zero), (e2, e1, e1), (e2, e1, e2), (e2, e1, e3), (e2, e2, one), (e2, e2, zero), (e2, e2, e1), (e2, e2, e2), (e2, e2, e3), (e2, e3, one), (e2, e3, zero), (e2, e3, e1), (e2, e3, e2), (e2, e3, e3), (e3, one, one), (e3, one, zero), (e3, one, e1), (e3, one, e2), (e3, one, e3), (e3, zero, one), (e3, zero, zero), (e3, zero, e1), (e3, zero, e2), (e3, zero, e3), (e3, e1, one), (e3, e1, zero), (e3, e1, e1), (e3, e1, e2), (e3, e1, e3), (e3, e2, one), (e3, e2, zero), (e3, e2, e1), (e3, e2, e2), (e3, e2, e3), (e3, e3, one), (e3, e3, zero), (e3, e3, e1), (e3, e3, e2), (e3, e3, e3)]
# body: And(le(e1, e1),
#     Implies(And(le(e1, e2), le(e2, e3)), le(e1, e3)),
#     Implies(And(le(e1, e2), le(e2, e1)), e1 == e2),
#     Or(le(e1, e2), le(e2, e1)),
#     le(zero, e1),
#     one != zero)
# instance: And(le(one, one),
#     Implies(And(le(one, one), le(one, one)), le(one, one)),
#     Implies(And(le(one, one), le(one, one)), one == one),
#     Or(le(one, one), le(one, one)),
#     le(zero, one),
#     one != zero)
# zip: [(e1, one), (e2, one), (e3, one)]
# And(And(le(one, one),
#         Implies(And(le(one, one), le(one, one)),
#                 le(one, one)),
#         Implies(And(le(one, one), le(one, one)), one == one),
#         Or(le(one, one), le(one, one)),
#         le(zero, one),
#         one != zero))

# %% [markdown]
# ## Invariants

# %%
# Inv: le(E1, E2) & E1 ~= E2 -> le(E1,ep(N1)) | ~le(E2,ep(N1))
# in other words: e1 < e2 ==> e1 <= ep(N1) or e2 > ep(N1)

def get_inv1(M: DistLockModel, S: DistLockState):
    e1, e2 = Consts('e1 e2', Epoch)
    n1 = Const('n1', Node)

    Inv = ForAll([e1, e2, n1],
        Implies(
            And(
                M.le(e1, e2),
                e1 != e2
            ),
            Or(
                M.le(e1, S.ep(n1)),
                Not(
                    M.le(e2, S.ep(n1))
                )
            )
        )
    )
    return Inv

M = DistLockModel()
S = M.get_state('pre')
# only for testing
inv1 = get_inv1(M, S)
inv1
# Out:
# ForAll([e1, e2, n1],
#        Implies(And(le(e1, e2), e1 != e2),
#                Or(le(e1, pre.ep(n1)),
#                   Not(le(e2, pre.ep(n1))))))

# %% [markdown]
# ### Invariant parser

# %%
invariants = """
le(E1, E2) & E1 ~= E2 -> le(E1,ep(N1)) | ~le(E2,ep(N1))
le(E1, E2) & E1 ~= E2 -> locked(E1,N1) | ~transfer(E1,N1) | ~transfer(E2,N1)
le(E1, E2) & E1 ~= E2 -> locked(E1,N1) | ~transfer(E1,N1) | ~le(E2,ep(N1))
le(E1, E2) & E1 ~= E2 -> le(E1,ep(N1)) | ~locked(E2,N1)
le(E1, E2) & E1 ~= E2 -> locked(E1,N1) | ~transfer(E1,N1) | ~locked(E2,N1)
le(E1, E2) & E1 ~= E2 -> le(E1,ep(N1)) | ~transfer(E1,N1) | ~transfer(E2,N1)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> ~le(E2,ep(N1)) | ~le(ep(N1),ep(N2)) | ~le(ep(N2),ep(N1))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | le(ep(N1),ep(N2)) | ~locked(E2,N2)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~transfer(E1,N1) | ~locked(E2,N2)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> locked(E1,N1) | ~transfer(E1,N1) | ~le(E2,ep(N2))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~held(N2) | ~transfer(E2,N1)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~transfer(E1,N1) | ~le(E2,ep(N2))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~locked(E2,N2) | ~le(ep(N2),ep(N1))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> locked(E1,N1) | ~transfer(E1,N1) | ~transfer(E2,N2)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | le(ep(N1),ep(N2)) | ~le(E2,ep(N2))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~transfer(E1,N1) | ~transfer(E2,N2)
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~transfer(E2,N1) | ~le(E2,ep(N2))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> le(E1,ep(N1)) | ~le(ep(N2),ep(N1)) | ~le(E2,ep(N2))
le(E1, E2) & E1 ~= E2 & N1 ~= N2 -> locked(E1,N1) | ~transfer(E1,N1) | ~locked(E2,N2)
locked(E1,N1) | ~transfer(E1,N1) | ~le(E1,ep(N1))
locked(E1,N1) | ~held(N1) | ~transfer(E1,N1)
le(E1,ep(N1)) | ~held(N1) | ~transfer(E1,N1)
transfer(E1,N1) | ~locked(E1,N1)
le(E1,ep(N1)) | ~locked(E1,N1)
N1 ~= N2 -> ~le(ep(N1),ep(N2)) | ~le(ep(N2),ep(N1)) | ~first=N1
N1 ~= N2 -> le(E1,ep(N1)) | le(ep(N1),ep(N2)) | ~locked(E1,N2)
N1 ~= N2 -> le(E1,ep(N1)) | le(ep(N1),ep(N2)) | ~le(E1,ep(N2))
N1 ~= N2 -> le(ep(N1),ep(N2)) | ~held(N2)
N1 ~= N2 -> ~held(N1) | ~le(ep(N1),ep(N2))
N1 ~= N2 -> locked(E1,N1) | ~held(N2) | ~transfer(E1,N1)
N1 ~= N2 -> le(ep(N1),ep(N2)) | le(ep(N2),ep(N1))
N1 ~= N2 -> le(E1,ep(N1)) | ~locked(E1,N2) | ~le(ep(N2),ep(N1))
N1 ~= N2 -> ~held(N1) | ~held(N2)
N1 ~= N2 -> locked(E1,N1) | ~transfer(E1,N1) | ~le(E1,ep(N2))
N1 ~= N2 -> ~locked(E1,N1) | ~locked(E1,N2)
N1 ~= N2 -> ~first=N1 | ~first=N2
N1 ~= N2 -> ~transfer(E1,N1) | ~transfer(E1,N2)
N1 ~= N2 -> le(E1,ep(N1)) | ~held(N1) | ~transfer(E1,N2)
N1 ~= N2 -> ~transfer(E1,N1) | ~locked(E1,N2)
N1 ~= N2 -> ~locked(E1,N1) | ~le(ep(N1),ep(N2)) | ~le(ep(N2),ep(N1))
N1 ~= N2 -> le(E1,ep(N1)) | ~held(N1) | ~locked(E1,N2)
N1 ~= N2 -> le(E1,ep(N1)) | ~le(ep(N2),ep(N1)) | ~le(E1,ep(N2))
N1 ~= N2 -> le(E1,ep(N1)) | ~held(N1) | ~le(E1,ep(N2))
N1 ~= N2 -> le(E1,ep(N1)) | ~held(N2) | ~transfer(E1,N1)
N1 ~= N2 -> le(E1,ep(N1)) | ~transfer(E1,N1) | ~le(E1,ep(N2))
""".replace("~=", "!=").strip().split("\n")

def parse(inv_str, vars):
    inv_str = inv_str.strip()

    if inv_str.count("->") > 1:
        raise Exception("Too many ->")

    if '->' in inv_str:
        left, right = inv_str.split('->')
        return f"Implies({parse(left, vars)},{parse(right, vars)})"

    if "&" in inv_str:
        parts = inv_str.split("&")
        return f"And([{','.join([parse(p, vars) for p in parts])}])"

    if "|" in inv_str:
        parts = inv_str.split("|")
        return f"Or([{','.join([parse(p, vars) for p in parts])}])"

    if "~" in inv_str:
        return f"Not({parse(inv_str[1:], vars)})"

    if "!=" in inv_str:
        left, right = inv_str.split("!=")
        return f"{parse(left, vars)} != {parse(right, vars)}"
    
    if "=" in inv_str:
        left, right = inv_str.split("=")
        return f"{parse(left, vars)} == {parse(right, vars)}"

    if inv_str.endswith(")"):
        first_brace_idx = inv_str.index("(")
        name = inv_str[:first_brace_idx]
        args = inv_str[first_brace_idx+1:-1].split(",")
        prefix = "M." if name == 'le' else "S."
        return f"{prefix}{name}({','.join([parse(a, vars) for a in args])})"

    if inv_str == "first":
        return "M.first"

    vars.add(inv_str)
    return inv_str

def get_inv_fn(fn_name, inv_str, only_code=False):
    vars = set()
    inv_fn_str = parse(inv_str, vars)

    nodes = [v for v in vars if v.startswith("N")]
    epochs = [v for v in vars if v.startswith("E")]

    code = []
    if len(nodes) == 1:
        code += [nodes[0] + " = Const('" + nodes[0] + "', Node)"]
    elif len(nodes) > 1:
        code += [", ".join(nodes) + " = Consts('" + " ".join(nodes) + "', Node)"]
    
    if len(epochs) == 1:
        code += [epochs[0] + " = Const('" + epochs[0] + "', Epoch)"]
    elif len(epochs) > 1:
        code += [", ".join(epochs) + " = Consts('" + " ".join(epochs) + "', Epoch)"]
    
    code += ["inv = ForAll([" + ", ".join(vars) + "], " + inv_fn_str + ")"]
    code += ["return inv"]

    code = f"def {fn_name}(M, S):\n\t" + "\n\t".join(code)
    if only_code:
        return code

    ldict = {}
    exec(code)
    exec(f"ldict['fn'] = {fn_name}")
    return ldict['fn']

all_invars = [get_inv_fn("inv_fn_" + str(i), inv) for i, inv in enumerate(invariants)]

# %%
M = DistLockModel()
S = M.get_state('pre')

print(invariants[0])
all_invars[0](M, S)
# Out:
# le(E1, E2) & E1 != E2 -> le(E1,ep(N1)) | ~le(E2,ep(N1))
# ForAll([E2, E1, N1],
#        Implies(And(le(E1, E2), E1 != E2),
#                Or(le(E1, pre.ep(N1)),
#                   Not(le(E2, pre.ep(N1))))))

# %% [markdown]
# ### Safety Condition

# %%
# Inv: safety property locked(E, N1) & locked(E, N2) -> N1 = N2

def get_safety_inv(M: DistLockModel, S: DistLockState):
    e1 = Const('e1', Epoch)
    n1, n2 = Consts('n1 n2', Node)

    Inv = ForAll([e1, n1, n2],
        Implies(
            And(
                S.locked(e1, n1),
                S.locked(e1, n2)
            ),
            n1 == n2
        )
    )

    return Inv

M = DistLockModel()
S = M.get_state('pre')
get_safety_inv(M, S) # only for testing
# Out:
# ForAll([e1, n1, n2],
#        Implies(And(pre.locked(e1, n1), pre.locked(e1, n2)),
#                n1 == n2))

# %% [markdown]
# ## Actions

# %%
# Grant action

def get_grant_action(M: DistLockModel, S1: DistLockState, S2: DistLockState):
    e = Const('e', Epoch)
    n1, n2 = Consts('n1 n2', Node)

    AcceptAction = ForAll([n1, n2, e],
        Implies(
            # precondition
            And(
                S1.held(n1),
                Not(M.le(e, S1.ep(n1)))
            ),
            # postcondition
            And(
                S2.transfer(e, n2),
                S2.held(n1) == False
            )
        )
    )

    return AcceptAction

M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')
get_grant_action(M, S1, S2) # only for testing
# Out:
# ForAll([n1, n2, e],
#        Implies(And(pre.held(n1), Not(le(e, pre.ep(n1)))),
#                And(post.transfer(e, n2),
#                    post.held(n1) == False)))

# %%
# Accept action

def get_accept_action(M: DistLockModel, S1: DistLockState, S2: DistLockState):
    e = Const('e', Epoch)
    n = Const('n', Node)

    AcceptAction = ForAll([n, e],
        Implies(
            And(
                S1.transfer(e, n),
                Not(M.le(e, S1.ep(n)))
            ),
            And(
                S2.held(n),
                S2.ep(n) == e,
                S2.locked(e, n)
            )
        )
    )

    return AcceptAction

M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')
get_accept_action(M, S1, S2) # only for testing
# Out:
# ForAll([n, e],
#        Implies(And(pre.transfer(e, n),
#                    Not(le(e, pre.ep(n)))),
#                And(post.held(n),
#                    post.ep(n) == e,
#                    post.locked(e, n))))

# %% [markdown]
# ## VCs

# %%
def get_init_vc(M: DistLockModel, inv_fn):
    vc = ( #Not(
        Implies(
            M.get_axioms(),
            Implies(
                M.get_init_state_cond(),
                inv_fn(M, M.get_state('init'))
            )
        )
    )
    return vc

M = DistLockModel()
vc = get_init_vc(M, get_inv1)
print(vc.sexpr()) # only for testing
# Out:
# (let ((a!1 (forall ((e1 Epoch) (e2 Epoch) (e3 Epoch))
#              (and (le e1 e1)
#                   (=> (and (le e1 e2) (le e2 e3)) (le e1 e3))
#                   (=> (and (le e1 e2) (le e2 e1)) (= e1 e2))
#                   (or (le e1 e2) (le e2 e1))
#                   (le zero e1)
#                   (distinct one zero))))
#       (a!2 (forall ((n Node) (e Epoch))
#              (and (= (init.held n) (= n first))
#                   (=> (distinct n first) (= (init.ep n) zero))
#                   (= (init.ep first) one)
#                   (= (init.transfer e n) false)
#                   (= (init.locked e n) false))))
#       (a!3 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (init.ep n1)) (not (le e2 (init.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1)))))
#   (=> a!1 (=> a!2 a!3)))

# %%
def get_inductiveness_vc(M: DistLockModel, S1: DistLockState, action_fn, S2: DistLockState, inv_fn):
    vc = ( #Not(
        Implies(
            M.get_axioms(),
            Implies(
                And(
                    inv_fn(M, S1),
                    action_fn(M, S1, S2),
                ),
                inv_fn(M, S2)
            )
        )
    )
    return vc

M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')
vc = get_inductiveness_vc(M, S1, get_accept_action, S2, get_inv1)
print(vc.sexpr()) # only for testing
# Out:
# (let ((a!1 (forall ((e1 Epoch) (e2 Epoch) (e3 Epoch))
#              (and (le e1 e1)
#                   (=> (and (le e1 e2) (le e2 e3)) (le e1 e3))
#                   (=> (and (le e1 e2) (le e2 e1)) (= e1 e2))
#                   (or (le e1 e2) (le e2 e1))
#                   (le zero e1)
#                   (distinct one zero))))
#       (a!2 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (pre.ep n1)) (not (le e2 (pre.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1))))
#       (a!3 (forall ((n Node) (e Epoch))
#              (let ((a!1 (and (pre.transfer e n) (not (le e (pre.ep n))))))
#                (=> a!1 (and (post.held n) (= (post.ep n) e) (post.locked e n))))))
#       (a!4 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (post.ep n1)) (not (le e2 (post.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1)))))
#   (=> a!1 (=> (and a!2 a!3) a!4)))

# %%
def get_safety_vc(M: DistLockModel, S: DistLockState, inv_fn, safety_fn):
    vc = ( # Not(
        Implies(
            M.get_axioms(),
            Implies(
                inv_fn(M, S),
                safety_fn(M, S)
            )
        )
    )
    return vc

M = DistLockModel()
S1 = M.get_state('pre')
vc = get_safety_vc(M, S1, get_inv1, get_safety_inv)
print(vc.sexpr()) # only for testing
# Out:
# (let ((a!1 (forall ((e1 Epoch) (e2 Epoch) (e3 Epoch))
#              (and (le e1 e1)
#                   (=> (and (le e1 e2) (le e2 e3)) (le e1 e3))
#                   (=> (and (le e1 e2) (le e2 e1)) (= e1 e2))
#                   (or (le e1 e2) (le e2 e1))
#                   (le zero e1)
#                   (distinct one zero))))
#       (a!2 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (pre.ep n1)) (not (le e2 (pre.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1))))
#       (a!3 (forall ((e1 Epoch) (n1 Node) (n2 Node))
#              (=> (and (pre.locked e1 n1) (pre.locked e1 n2)) (= n1 n2)))))
#   (=> a!1 (=> a!2 a!3)))

# %%
# Inductiveness check using instantiatiojn
# ax & inv_pre & trans & \not inv_post
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')
inv_post = And([inv(M,S2).body() for inv in all_invars[:1]])
# print(inv_post)
inst_terms = extract_terms(inv_post)
# print(inst_terms)
# print(M.get_axioms())
# s1 = Solver()
# s1.add(M.get_axioms())
# print(s1.check())
ax_instantiation = instantiate(M.get_axioms(), inst_terms)
print(ax_instantiation)
# inv_pre_instantiation = And([instantiate(inv(M,S1), inst_terms) for inv in all_invars[:1]])
# trans_instantiation = instantiate(get_accept_action(M,S1,S2), inst_terms)
sol = Solver()
# inv_post
sol.add(ax_instantiation)
print(sol.sexpr())
print(sol.check())
# sol
# sol.add(ax_instantiation)
# sol
#sol.add(simplify(And(ax_instantiation, inv_pre_instantiation, trans_instantiation, Not(inv_post))))
# print('HereIam')
#print(sol.sexpr())
#sol
#sol.check()
# Out:
# {Node: set(), Epoch: {Var(2), Var(1), post.ep(Var(0))}}
# ([e1, e2, e3], And(le(e1, e1),
#     Implies(And(le(e1, e2), le(e2, e3)), le(e1, e3)),
#     Implies(And(le(e1, e2), le(e2, e1)), e1 == e2),
#     Or(le(e1, e2), le(e2, e1)),
#     le(zero, e1),
#     one != zero))
# quant_vars: [e1, e2, e3]
# instantiations: [(Var(2), Var(2), Var(2)), (Var(2), Var(2), Var(1)), (Var(2), Var(2), post.ep(Var(0))), (Var(2), Var(1), Var(2)), (Var(2), Var(1), Var(1)), (Var(2), Var(1), post.ep(Var(0))), (Var(2), post.ep(Var(0)), Var(2)), (Var(2), post.ep(Var(0)), Var(1)), (Var(2), post.ep(Var(0)), post.ep(Var(0))), (Var(1), Var(2), Var(2)), (Var(1), Var(2), Var(1)), (Var(1), Var(2), post.ep(Var(0))), (Var(1), Var(1), Var(2)), (Var(1), Var(1), Var(1)), (Var(1), Var(1), post.ep(Var(0))), (Var(1), post.ep(Var(0)), Var(2)), (Var(1), post.ep(Var(0)), Var(1)), (Var(1), post.ep(Var(0)), post.ep(Var(0))), (post.ep(Var(0)), Var(2), Var(2)), (post.ep(Var(0)), Var(2), Var(1)), (post.ep(Var(0)), Var(2), post.ep(Var(0))), (post.ep(Var(0)), Var(1), Var(2)), (post.ep(Var(0)), Var(1), Var(1)), (post.ep(Var(0)), Var(1), post.ep(Var(0))), (post.ep(Var(0)), post.ep(Var(0)), Var(2)), (post.ep(Var(0)), post.ep(Var(0)), Var(1)), (post.ep(Var(0)), post.ep(Var(0)), post.ep(Var(0)))]
# body: And(le(e1, e1),
#     Implies(And(le(e1, e2), le(e2, e3)), le(e1, e3)),
#     Implies(And(le(e1, e2), le(e2, e1)), e1 == e2),
#     Or(le(e1, e2), le(e2, e1)),
#     le(zero, e1),
#     one != zero)
# instance: And(le(Var(2), Var(2)),
#     Implies(And(le(Var(2), Var(2)), le(Var(2), Var(2))),
#             le(Var(2), Var(2))),
#     Implies(And(le(Var(2), Var(2)), le(Var(2), Var(2))),
#             Var(2) == Var(2)),
#     Or(le(Var(2), Var(2)), le(Var(2), Var(2))),
#     le(zero, Var(2)),
#     one != zero)
# zip: [(e1, Var(2)), (e2, Var(2)), (e3, Var(2))]
# And(And(le(Var(2), Var(2)),
#         Implies(And(le(Var(2), Var(2)), le(Var(2), Var(2))),
#                 le(Var(2), Var(2))),
#         Implies(And(le(Var(2), Var(2)), le(Var(2), Var(2))),
#                 Var(2) == Var(2)),
#         Or(le(Var(2), Var(2)), le(Var(2), Var(2))),
#         le(zero, Var(2)),
#         one != zero))
# (declare-sort Epoch 0)
# (declare-fun zero () Epoch)
# (declare-fun one () Epoch)
# (declare-fun le (Epoch Epoch) Bool)
# (assert (and (le (:var 2) (:var 2))
#      (=> (and (le (:var 2) (:var 2)) (le (:var 2) (:var 2)))
#          (le (:var 2) (:var 2)))
#      (=> (and (le (:var 2) (:var 2)) (le (:var 2) (:var 2)))
#          (= (:var 2) (:var 2)))
#      (or (le (:var 2) (:var 2)) (le (:var 2) (:var 2)))
#      (le zero (:var 2))
#      (distinct one zero)))
#
# unknown

# %%
s = Solver()
new = DeclareSort('new')
x = Const('x',new)
f = Function('f', new, IntSort())
s.add(And(f(x)==5))
s.check()
s.model()
# Out:
# [x = new!val!0, f = [else -> 5]]

# %% [markdown]
# ## End to end examples

# %% [markdown]
# ### Example 1

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = lambda M,S: And(all_invars[0](M,S), all_invars[1](M,S))

solver = Solver()
# solver.add()
cond = Not(And(
    #get_init_vc(M, inv),
    get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
))
#cond
solver.add(cond)
solver.check()
# Out:
# Not(And(Implies(ForAll([e1, e2, e3],
#                        And(le(e1, e1),
#                            Implies(And(le(e1, e2),
#                                        le(e2, e3)),
#                                    le(e1, e3)),
#                            Implies(And(le(e1, e2),
#                                        le(e2, e1)),
#                                    e1 == e2),
#                            Or(le(e1, e2), le(e2, e1)),
#                            le(zero, e1),
#                            one != zero)),
#                 Implies(And(And(ForAll([E2, E1, N1],
#                                        Implies(And(le(E1,
#                                         E2),
#                                         E1 != E2),
#                                         Or(le(E1,
#                                         pre.ep(N1)),
#                                         Not(le(E2,
#                                         pre.ep(N1)))))),
#                                 ForAll([E2, E1, N1],
#                                        Implies(And(le(E1,
#                                         E2),
#                                         E1 != E2),
#                                         Or(pre.locked(E1,
#                                         N1),
#                                         Not(pre.transfer(E1,
#                                         N1)),
#                                         Not(pre.transfer(E2,
#                                         N1)))))),
#                             ForAll([n, e],
#                                    Implies(And(pre.transfer(e,
#                                         n),
#                                         Not(le(e, pre.ep(n)))),
#                                         And(post.held(n),
#                                         post.ep(n) == e,
#                                         post.locked(e, n))))),
#                         And(ForAll([E2, E1, N1],
#                                    Implies(And(le(E1, E2),
#                                         E1 != E2),
#                                         Or(le(E1,
#                                         post.ep(N1)),
#                                         Not(le(E2,
#                                         post.ep(N1)))))),
#                             ForAll([E2, E1, N1],
#                                    Implies(And(le(E1, E2),
#                                         E1 != E2),
#                                         Or(post.locked(E1,
#                                         N1),
#                                         Not(post.transfer(E1,
#                                         N1)),
#                                         Not(post.transfer(E2,
#                                         N1))))))))))

# %% [markdown]
# The above tells that `get_inv1()` invariant satisfies the initial condition and is also inductive.

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = get_inv1

solver = Solver()
# solver.add()
solver.add(Not(And(
    get_init_vc(M, inv),
    get_inductiveness_vc(M, S1, get_accept_action, S2, inv),
    get_safety_vc(M, S1, inv, get_safety_inv)
)))
solver.check()
# Out:
# sat

# %% [markdown]
# However, it does not imply the safety condition.

# %% [markdown]
# ### Example 2

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = get_safety_inv # notice this <-- it's get_safety_inv and not get_inv1.

solver = Solver()
# solver.add()
solver.add(Not(And(
    get_init_vc(M, inv),
    # get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
)))
solver.check()
# Out:
# unsat

# %% [markdown]
# The safety invariant satisfies the initial condition.

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = get_safety_inv # notice this <-- it's get_safety_inv and not get_inv1.

solver = Solver()
# solver.add()
solver.add(Not(And(
    get_init_vc(M, inv),
    get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
)))
solver.check()
# Out:
# sat

# %% [markdown]
# However, the safety invariant isn't inductive.

# %% [markdown]
# ### Example 3

# %%
M = DistLockModel()
S1 = M.get_state('pre')

solver = Solver()
solver.add(Not(And(
    get_init_vc(M, get_inv1),
    get_safety_vc(M, S1, get_inv1, get_safety_inv))
))
solver.check()
# Out:
# sat

# %% [markdown]
# This shows that `get_inv1` doesn't imply safety condition.

# %% [markdown]
# The conditions given to the solver are shown below:

# %%
print(solver.sexpr())
# Out:
# (declare-sort Node 0)
# (declare-sort Epoch 0)
# (declare-fun pre.locked (Epoch Node) Bool)
# (declare-fun le (Epoch Epoch) Bool)
# (declare-fun pre.ep (Node) Epoch)
# (declare-fun zero () Epoch)
# (declare-fun one () Epoch)
# (declare-fun init.ep (Node) Epoch)
# (declare-fun init.locked (Epoch Node) Bool)
# (declare-fun init.transfer (Epoch Node) Bool)
# (declare-fun first () Node)
# (declare-fun init.held (Node) Bool)
# (assert (let ((a!1 (forall ((e1 Epoch) (e2 Epoch) (e3 Epoch))
#              (and (le e1 e1)
#                   (=> (and (le e1 e2) (le e2 e3)) (le e1 e3))
#                   (=> (and (le e1 e2) (le e2 e1)) (= e1 e2))
#                   (or (le e1 e2) (le e2 e1))
#                   (le zero e1)
#                   (distinct one zero))))
#       (a!2 (forall ((n Node) (e Epoch))
#              (and (= (init.held n) (= n first))
#                   (=> (distinct n first) (= (init.ep n) zero))
#                   (= (init.ep first) one)
#                   (= (init.transfer e n) false)
#                   (= (init.locked e n) false))))
#       (a!3 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (init.ep n1)) (not (le e2 (init.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1))))
#       (a!4 (forall ((e1 Epoch) (e2 Epoch) (n1 Node))
#              (let ((a!1 (or (le e1 (pre.ep n1)) (not (le e2 (pre.ep n1))))))
#                (=> (and (le e1 e2) (distinct e1 e2)) a!1))))
#       (a!5 (forall ((e1 Epoch) (n1 Node) (n2 Node))
#              (=> (and (pre.locked e1 n1) (pre.locked e1 n2)) (= n1 n2)))))
#   (not (and (=> a!1 (=> a!2 a!3)) (=> a!1 (=> a!4 a!5))))))
# (rmodel->model-converter-wrapper
# e1!121 -> Epoch!val!2
# n1!120 -> Node!val!1
# zero -> Epoch!val!5
# e2!117 -> Epoch!val!3
# one -> Epoch!val!6
# e1!118 -> Epoch!val!0
# n1!116 -> Node!val!0
# n2!119 -> Node!val!2
# elem!123 -> Epoch!val!4
# elem!212 -> Node!val!0
# le -> {
#   (le!215 (k!214 (:var 0)) (k!214 (:var 1)))
# }
# init.ep -> {
#   Epoch!val!1
# }
# le!215 -> {
#   (or (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!6))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!4))
#       (and (= (:var 0) Epoch!val!3) (= (:var 1) Epoch!val!4))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!5))
#       (and (= (:var 0) Epoch!val!1) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!1) (= (:var 1) Epoch!val!2))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!2))
#       (and (= (:var 0) Epoch!val!2) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!4))
#       (and (= (:var 0) Epoch!val!3) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!3) (= (:var 1) Epoch!val!3))
#       (and (= (:var 0) Epoch!val!1) (= (:var 1) Epoch!val!1))
#       (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!3))
#       (and (= (:var 0) Epoch!val!0) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!4) (= (:var 1) Epoch!val!4))
#       (and (= (:var 0) Epoch!val!2) (= (:var 1) Epoch!val!2))
#       (and (= (:var 0) Epoch!val!4) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!3))
#       (and (= (:var 0) Epoch!val!1) (= (:var 1) Epoch!val!3))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!1))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!6))
#       (and (= (:var 0) Epoch!val!3) (= (:var 1) Epoch!val!2))
#       (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!1))
#       (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!1) (= (:var 1) Epoch!val!4))
#       (and (= (:var 0) Epoch!val!6) (= (:var 1) Epoch!val!2))
#       (and (= (:var 0) Epoch!val!5) (= (:var 1) Epoch!val!0))
#       (and (= (:var 0) Epoch!val!2) (= (:var 1) Epoch!val!4)))
# }
# pre.ep -> {
#   Epoch!val!5
# }
# pre.locked -> {
#   true
# }
# k!214 -> {
#   Epoch!val!6 -> Epoch!val!6
#   Epoch!val!0 -> Epoch!val!0
#   Epoch!val!5 -> Epoch!val!5
#   Epoch!val!1 -> Epoch!val!1
#   Epoch!val!3 -> Epoch!val!3
#   Epoch!val!4 -> Epoch!val!4
#   else -> Epoch!val!2
# }
# )

# %% [markdown]
# The counter example given by Z3 is shown below

# %%
m = solver.model()
print(m.sexpr())
# Out:
# ;; universe for Node:
# ;;   Node!val!1 Node!val!2 Node!val!0
# ;; -----------
# ;; definitions for universe elements:
# (declare-fun Node!val!1 () Node)
# (declare-fun Node!val!2 () Node)
# (declare-fun Node!val!0 () Node)
# ;; cardinality constraint:
# (forall ((x Node)) (or (= x Node!val!1) (= x Node!val!2) (= x Node!val!0)))
# ;; -----------
# ;; universe for Epoch:
# ;;   Epoch!val!3 Epoch!val!0 Epoch!val!4 Epoch!val!1 Epoch!val!5 Epoch!val!6 Epoch!val!2
# ;; -----------
# ;; definitions for universe elements:
# (declare-fun Epoch!val!3 () Epoch)
# (declare-fun Epoch!val!0 () Epoch)
# (declare-fun Epoch!val!4 () Epoch)
# (declare-fun Epoch!val!1 () Epoch)
# (declare-fun Epoch!val!5 () Epoch)
# (declare-fun Epoch!val!6 () Epoch)
# (declare-fun Epoch!val!2 () Epoch)
# ;; cardinality constraint:
# (forall ((x Epoch))
#         (or (= x Epoch!val!3)
#             (= x Epoch!val!0)
#             (= x Epoch!val!4)
#             (= x Epoch!val!1)
#             (= x Epoch!val!5)
#             (= x Epoch!val!6)
#             (= x Epoch!val!2)))
# ;; -----------
# (define-fun zero () Epoch
#   Epoch!val!5)
# (define-fun one () Epoch
#   Epoch!val!6)
# (define-fun le ((x!0 Epoch) (x!1 Epoch)) Bool
#   (let ((a!1 (ite (= x!0 Epoch!val!5)
#                   Epoch!val!5
#                   (ite (= x!0 Epoch!val!0)
#                        Epoch!val!0
#                        (ite (= x!0 Epoch!val!6) Epoch!val!6 Epoch!val!2))))
#         (a!3 (ite (= x!1 Epoch!val!5)
#                   Epoch!val!5
#                   (ite (= x!1 Epoch!val!0)
#                        Epoch!val!0
#                        (ite (= x!1 Epoch!val!6) Epoch!val!6 Epoch!val!2)))))
#   (let ((a!2 (ite (= x!0 Epoch!val!4)
#                   Epoch!val!4
#                   (ite (= x!0 Epoch!val!3)
#                        Epoch!val!3
#                        (ite (= x!0 Epoch!val!1) Epoch!val!1 a!1))))
#         (a!4 (ite (= x!1 Epoch!val!4)
#                   Epoch!val!4
#                   (ite (= x!1 Epoch!val!3)
#                        Epoch!val!3
#                        (ite (= x!1 Epoch!val!1) Epoch!val!1 a!3)))))
#     (or (and (= a!2 Epoch!val!3) (= a!4 Epoch!val!3))
#         (and (= a!2 Epoch!val!4) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!2) (= a!4 Epoch!val!2))
#         (and (= a!2 Epoch!val!3) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!1))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!3))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!3) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!1) (= a!4 Epoch!val!1))
#         (and (= a!2 Epoch!val!4) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!1) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!2))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!1))
#         (and (= a!2 Epoch!val!6) (= a!4 Epoch!val!6))
#         (and (= a!2 Epoch!val!1) (= a!4 Epoch!val!3))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!3))
#         (and (= a!2 Epoch!val!0) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!2) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!2) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!1) (= a!4 Epoch!val!0))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!6))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!4))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!2))
#         (and (= a!2 Epoch!val!1) (= a!4 Epoch!val!2))
#         (and (= a!2 Epoch!val!3) (= a!4 Epoch!val!2))
#         (and (= a!2 Epoch!val!5) (= a!4 Epoch!val!5))))))
# (define-fun init.ep ((x!0 Node)) Epoch
#   Epoch!val!1)
# (define-fun pre.ep ((x!0 Node)) Epoch
#   Epoch!val!5)
# (define-fun pre.locked ((x!0 Epoch) (x!1 Node)) Bool
#   true)

# %% [markdown]
# Another way to access the counter example model is as shown below:

# %%
interp = M.get_interp(m)
set_param(max_lines=1000)
print(interp)
# Out:
# {'zero': Epoch!val!5, 'one': Epoch!val!6, 'le': [else ->
#  Or(And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!0),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!6),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!4),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!1,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!3,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!2),
#     And(If(Var(0) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(0) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(0) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(0) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(0) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(0) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5,
#         If(Var(1) == Epoch!val!4,
#            Epoch!val!4,
#            If(Var(1) == Epoch!val!3,
#               Epoch!val!3,
#               If(Var(1) == Epoch!val!1,
#                  Epoch!val!1,
#                  If(Var(1) == Epoch!val!5,
#                     Epoch!val!5,
#                     If(Var(1) == Epoch!val!0,
#                        Epoch!val!0,
#                        If(Var(1) == Epoch!val!6,
#                           Epoch!val!6,
#                           Epoch!val!2)))))) ==
#         Epoch!val!5))], 'init.ep': [else -> Epoch!val!1], 'pre.ep': [else -> Epoch!val!5], 'pre.locked': [else -> True]}

# %% [markdown]
# ## Full verification

# %% [markdown]
# This code below first checks if all the invariants produced by DistAI:
# - Satisfy the initial state
# - Imply Safety
# - Are inductive

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = lambda M, S: And(*[inv(M, S) for inv in all_invars])

solver = Solver()
solver.add(Not(And(
    get_init_vc(M, inv),
    # get_safety_vc(M, S1, inv, get_safety_inv)
    # get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
)))
solver.check()
# Out:
# unsat

# %% [markdown]
# Yay, invariants satisfy the initial conditions

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = lambda M, S: And(*[inv(M, S) for inv in all_invars])

solver = Solver()
solver.add(Not(And(
    # get_init_vc(M, inv),
    get_safety_vc(M, S1, inv, get_safety_inv)
    # get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
)))
solver.check()
# Out:
# unsat

# %% [markdown]
# Yay, invariants imply the safety condition

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = lambda M, S: And(*[inv(M, S) for inv in all_invars])

solver = Solver()
cond1 = Not(And(
    # get_init_vc(M, inv),
    # get_safety_vc(M, S1, inv, get_safety_inv)
    get_inductiveness_vc(M, S1, get_accept_action, S2, inv)
))
cond1 = z3.simplify(cond1)

#solver.check()
# Out:
# Not(Or(And(ForAll([N1, E1, E2],
#                   Or(Not(le(E2, post.ep(N1))),
#                      le(E1, post.ep(N1)),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, E2],
#                   Or(Not(post.transfer(E1, N1)),
#                      post.locked(E1, N1),
#                      Not(post.transfer(E2, N1)),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, E2],
#                   Or(Not(le(E2, post.ep(N1))),
#                      Not(post.transfer(E1, N1)),
#                      post.locked(E1, N1),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, E2],
#                   Or(Not(post.locked(E2, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, E2],
#                   Or(Not(post.locked(E2, N1)),
#                      Not(post.transfer(E1, N1)),
#                      post.locked(E1, N1),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, E2],
#                   Or(Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(post.transfer(E2, N1)),
#                      Not(And(le(E1, E2), Not(E1 == E2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(le(post.ep(N1), post.ep(N2))),
#                      Not(le(E2, post.ep(N1))),
#                      Not(le(post.ep(N2), post.ep(N1))),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(le(E1, post.ep(N1)),
#                      le(post.ep(N1), post.ep(N2)),
#                      Not(post.locked(E2, N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(post.locked(E2, N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(post.locked(E1, N1),
#                      Not(post.transfer(E1, N1)),
#                      Not(le(E2, post.ep(N2))),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(post.held(N2)),
#                      Not(post.transfer(E2, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(le(E2, post.ep(N2))),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(le(E1, post.ep(N1)),
#                      Not(le(post.ep(N2), post.ep(N1))),
#                      Not(post.locked(E2, N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(post.locked(E1, N1),
#                      Not(post.transfer(E1, N1)),
#                      Not(post.transfer(E2, N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(le(E1, post.ep(N1)),
#                      Not(le(E2, post.ep(N2))),
#                      le(post.ep(N1), post.ep(N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(post.transfer(E1, N1)),
#                      Not(post.transfer(E2, N2)),
#                      le(E1, post.ep(N1)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(Not(post.transfer(E2, N1)),
#                      le(E1, post.ep(N1)),
#                      Not(le(E2, post.ep(N2))),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(le(E1, post.ep(N1)),
#                      Not(le(post.ep(N2), post.ep(N1))),
#                      Not(le(E2, post.ep(N2))),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1, N2, E2],
#                   Or(post.locked(E1, N1),
#                      Not(post.transfer(E1, N1)),
#                      Not(post.locked(E2, N2)),
#                      Not(And(le(E1, E2),
#                              Not(E1 == E2),
#                              Not(N1 == N2))))),
#            ForAll([N1, E1],
#                   Or(post.locked(E1, N1),
#                      Not(post.transfer(E1, N1)),
#                      Not(le(E1, post.ep(N1))))),
#            ForAll([N1, E1],
#                   Or(post.locked(E1, N1),
#                      Not(post.held(N1)),
#                      Not(post.transfer(E1, N1)))),
#            ForAll([N1, E1],
#                   Or(Not(post.held(N1)),
#                      Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1)))),
#            ForAll([N1, E1],
#                   Or(post.transfer(E1, N1),
#                      Not(post.locked(E1, N1)))),
#            ForAll([N1, E1],
#                   Or(le(E1, post.ep(N1)),
#                      Not(post.locked(E1, N1)))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      Not(le(post.ep(N2), post.ep(N1))),
#                      Not(le(post.ep(N1), post.ep(N2))),
#                      Not(first == N1))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      le(post.ep(N1), post.ep(N2)),
#                      Not(post.locked(E1, N2)),
#                      le(E1, post.ep(N1)))),
#            ForAll([N1, E1, N2],
#                   Or(Not(le(E1, post.ep(N2))),
#                      N1 == N2,
#                      le(post.ep(N1), post.ep(N2)),
#                      le(E1, post.ep(N1)))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      Not(post.held(N2)),
#                      le(post.ep(N1), post.ep(N2)))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      Not(post.held(N1)),
#                      Not(le(post.ep(N1), post.ep(N2))))),
#            ForAll([N1, E1, N2],
#                   Or(Not(post.held(N2)),
#                      N1 == N2,
#                      Not(post.transfer(E1, N1)),
#                      post.locked(E1, N1))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      le(post.ep(N1), post.ep(N2)),
#                      le(post.ep(N2), post.ep(N1)))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.locked(E1, N2)),
#                      le(E1, post.ep(N1)),
#                      Not(le(post.ep(N2), post.ep(N1))))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      Not(post.held(N1)),
#                      Not(post.held(N2)))),
#            ForAll([N1, E1, N2],
#                   Or(Not(le(E1, post.ep(N2))),
#                      N1 == N2,
#                      Not(post.transfer(E1, N1)),
#                      post.locked(E1, N1))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.locked(E1, N2)),
#                      Not(post.locked(E1, N1)))),
#            ForAll([N1, N2],
#                   Or(N1 == N2,
#                      Not(first == N2),
#                      Not(first == N1))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.transfer(E1, N1)),
#                      Not(post.transfer(E1, N2)))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      le(E1, post.ep(N1)),
#                      Not(post.held(N1)),
#                      Not(post.transfer(E1, N2)))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.locked(E1, N2)),
#                      Not(post.transfer(E1, N1)))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.locked(E1, N1)),
#                      Not(le(post.ep(N1), post.ep(N2))),
#                      Not(le(post.ep(N2), post.ep(N1))))),
#            ForAll([N1, E1, N2],
#                   Or(N1 == N2,
#                      Not(post.locked(E1, N2)),
#                      le(E1, post.ep(N1)),
#                      Not(post.held(N1)))),
#            ForAll([N1, E1, N2],
#                   Or(Not(le(E1, post.ep(N2))),
#                      N1 == N2,
#                      le(E1, post.ep(N1)),
#                      Not(le(post.ep(N2), post.ep(N1))))),
#            ForAll([N1, E1, N2],
#                   Or(Not(le(E1, post.ep(N2))),
#                      N1 == N2,
#                      le(E1, post.ep(N1)),
#                      Not(post.held(N1)))),
#            ForAll([N1, E1, N2],
#                   Or(Not(post.held(N2)),
#                      N1 == N2,
#                      Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1)))),
#            ForAll([N1, E1, N2],
#                   Or(Not(le(E1, post.ep(N2))),
#                      N1 == N2,
#                      Not(post.transfer(E1, N1)),
#                      le(E1, post.ep(N1))))),
#        Not(ForAll([e1, e2, e3],
#                   And(le(e1, e1),
#                       Or(Not(And(le(e1, e2), le(e2, e3))),
#                          le(e1, e3)),
#                       Or(Not(And(le(e1, e2), le(e2, e1))),
#                          e1 == e2),
#                       Or(le(e1, e2), le(e2, e1)),
#                       le(zero, e1),
#                       Not(one == zero)))),
#        Not(And(ForAll([N1, E1, E2],
#                       Or(Not(le(E2, pre.ep(N1))),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2), Not(E1 == E2))))),
#                ForAll([N1, E1, E2],
#                       Or(pre.locked(E1, N1),
#                          Not(And(le(E1, E2), Not(E1 == E2))),
#                          Not(pre.transfer(E1, N1)),
#                          Not(pre.transfer(E2, N1)))),
#                ForAll([N1, E1, E2],
#                       Or(Not(le(E2, pre.ep(N1))),
#                          pre.locked(E1, N1),
#                          Not(And(le(E1, E2), Not(E1 == E2))),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1, E2],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2), Not(E1 == E2))),
#                          Not(pre.locked(E2, N1)))),
#                ForAll([N1, E1, E2],
#                       Or(pre.locked(E1, N1),
#                          Not(And(le(E1, E2), Not(E1 == E2))),
#                          Not(pre.transfer(E1, N1)),
#                          Not(pre.locked(E2, N1)))),
#                ForAll([N1, E1, E2],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2), Not(E1 == E2))),
#                          Not(pre.transfer(E1, N1)),
#                          Not(pre.transfer(E2, N1)))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(pre.ep(N2), pre.ep(N1))),
#                          Not(le(pre.ep(N1), pre.ep(N2))),
#                          Not(le(E2, pre.ep(N1))),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(pre.locked(E2, N2)),
#                          le(pre.ep(N1), pre.ep(N2)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(pre.transfer(E1, N1)),
#                          le(E1, pre.ep(N1)),
#                          Not(pre.locked(E2, N2)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(E2, pre.ep(N2))),
#                          Not(pre.transfer(E1, N1)),
#                          pre.locked(E1, N1),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(pre.held(N2)),
#                          Not(pre.transfer(E2, N1)),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(E2, pre.ep(N2))),
#                          Not(pre.transfer(E1, N1)),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(pre.ep(N2), pre.ep(N1))),
#                          le(E1, pre.ep(N1)),
#                          Not(pre.locked(E2, N2)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(pre.transfer(E1, N1)),
#                          pre.locked(E1, N1),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))),
#                          Not(pre.transfer(E2, N2)))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(E2, pre.ep(N2))),
#                          le(E1, pre.ep(N1)),
#                          le(pre.ep(N1), pre.ep(N2)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(pre.transfer(E1, N1)),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))),
#                          Not(pre.transfer(E2, N2)))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(E2, pre.ep(N2))),
#                          Not(pre.transfer(E2, N1)),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(le(E2, pre.ep(N2))),
#                          Not(le(pre.ep(N2), pre.ep(N1))),
#                          le(E1, pre.ep(N1)),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1, N2, E2],
#                       Or(Not(pre.transfer(E1, N1)),
#                          Not(pre.locked(E2, N2)),
#                          pre.locked(E1, N1),
#                          Not(And(le(E1, E2),
#                                  Not(E1 == E2),
#                                  Not(N1 == N2))))),
#                ForAll([N1, E1],
#                       Or(Not(le(E1, pre.ep(N1))),
#                          pre.locked(E1, N1),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1],
#                       Or(Not(pre.held(N1)),
#                          pre.locked(E1, N1),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(pre.held(N1)),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1],
#                       Or(pre.transfer(E1, N1),
#                          Not(pre.locked(E1, N1)))),
#                ForAll([N1, E1],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(pre.locked(E1, N1)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          Not(le(pre.ep(N1), pre.ep(N2))),
#                          Not(le(pre.ep(N2), pre.ep(N1))),
#                          Not(first == N1))),
#                ForAll([N1, E1, N2],
#                       Or(le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          le(pre.ep(N1), pre.ep(N2)),
#                          Not(pre.locked(E1, N2)))),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(E1, pre.ep(N2))),
#                          le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          le(pre.ep(N1), pre.ep(N2)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          Not(pre.held(N2)),
#                          le(pre.ep(N1), pre.ep(N2)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          Not(pre.held(N1)),
#                          Not(le(pre.ep(N1), pre.ep(N2))))),
#                ForAll([N1, E1, N2],
#                       Or(N1 == N2,
#                          Not(pre.held(N2)),
#                          pre.locked(E1, N1),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          le(pre.ep(N1), pre.ep(N2)),
#                          le(pre.ep(N2), pre.ep(N1)))),
#                ForAll([N1, E1, N2],
#                       Or(le(E1, pre.ep(N1)),
#                          Not(le(pre.ep(N2), pre.ep(N1))),
#                          N1 == N2,
#                          Not(pre.locked(E1, N2)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          Not(pre.held(N1)),
#                          Not(pre.held(N2)))),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(E1, pre.ep(N2))),
#                          N1 == N2,
#                          pre.locked(E1, N1),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1, N2],
#                       Or(N1 == N2,
#                          Not(pre.locked(E1, N1)),
#                          Not(pre.locked(E1, N2)))),
#                ForAll([N1, N2],
#                       Or(N1 == N2,
#                          Not(first == N2),
#                          Not(first == N1))),
#                ForAll([N1, E1, N2],
#                       Or(N1 == N2,
#                          Not(pre.transfer(E1, N2)),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1, N2],
#                       Or(le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          Not(pre.held(N1)),
#                          Not(pre.transfer(E1, N2)))),
#                ForAll([N1, E1, N2],
#                       Or(N1 == N2,
#                          Not(pre.locked(E1, N2)),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(pre.ep(N2), pre.ep(N1))),
#                          Not(le(pre.ep(N1), pre.ep(N2))),
#                          N1 == N2,
#                          Not(pre.locked(E1, N1)))),
#                ForAll([N1, E1, N2],
#                       Or(le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          Not(pre.held(N1)),
#                          Not(pre.locked(E1, N2)))),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(E1, pre.ep(N2))),
#                          le(E1, pre.ep(N1)),
#                          Not(le(pre.ep(N2), pre.ep(N1))),
#                          N1 == N2)),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(E1, pre.ep(N2))),
#                          le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          Not(pre.held(N1)))),
#                ForAll([N1, E1, N2],
#                       Or(le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          Not(pre.held(N2)),
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([N1, E1, N2],
#                       Or(Not(le(E1, pre.ep(N2))),
#                          le(E1, pre.ep(N1)),
#                          N1 == N2,
#                          Not(pre.transfer(E1, N1)))),
#                ForAll([n, e],
#                       Or(Not(And(pre.transfer(e, n),
#                                  Not(le(e, pre.ep(n))))),
#                          And(post.held(n),
#                              post.ep(n) == e,
#                              post.locked(e, n))))))))

# %% [markdown]
# And....Z3 chokes on the inductive invariants (wrt the accept action)

# %%
M = DistLockModel()
S1 = M.get_state('pre')
S2 = M.get_state('post')

inv = lambda M, S: And(*[inv(M, S) for inv in all_invars])

solver = Solver()
solver.add(Not(And(
    # get_init_vc(M, inv),
    # get_safety_vc(M, S1, inv, get_safety_inv)
    get_inductiveness_vc(M, S1, get_grant_action, S2, inv)
)))
solver.check()

# %% [markdown]
# It also chokes on the inductive invariants (wrt the grant action)
